# %%
# Importing libraries
import numpy as np
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel, Word2Vec
import spacy
from nltk.corpus import stopwords
import pyLDAvis
import pyLDAvis.gensim
import pandas as pd
import warnings
from gensim.models import TfidfModel

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# <br>
# <p style="font-family:consolas;font-size:200%;">Data Understanding:</p>
# <hr>

# %% [markdown]
# <div>
# <p style="font-size:120%;line-height:1.4">
# The dataset we will be using is the <a href="https://www.kaggle.com/datasets/rounakbanik/ted-talks?select=transcripts.csv">following</a>. It contains transcripts and URL information about all audio-video recordings of TED Talks uploaded to the official TED.com website until September 21st, 2017. Overall, this TED Talks dataset is a valuable resource for natural language processing and machine learning research, as it provides a large amount of text data along with additional metadata about the talks.
#     </p>
#
# </div>

# %%
# Importing data
def load_transcripts(file_path):
    data = pd.read_csv(file_path)['transcript']
    return data

transcripts = load_transcripts('transcripts.csv')

# %%
# Data comprehension
print("Data structure:")
print("Number of TED Talks:", len(transcripts))
print("Sample TED Talk transcript:")
print(transcripts[0])
# Out:
# Data structure:
# Number of TED Talks: 2467
# Sample TED Talk transcript:
# ...

# %% [markdown]
# <br>
# <p style="font-family:consolas;font-size:200%;">Data Preprocessing:</p>
# <hr>

# %%
# Preprocessing: Tokenization, Stopwords removal, Lemmatization
stopwords = stopwords.words("english")

def preprocess_text(text):
    # Load English language model
    nlp = spacy.load("en_core_web_sm", disable=["parser", "ner"])
    # Tokenize the text using Spacy
    doc = nlp(text)
    # Lemmatize tokens that are nouns, adjectives, verbs, or adverbs
    tokens = [token.lemma_ for token in doc if token.pos_ in ["NOUN", "ADJ", "VERB", "ADV"]]
    # Join the preprocessed tokens back into a string
    preprocessed_text = " ".join(tokens)
    return preprocessed_text

data_preprocessed = transcripts.apply(preprocess_text)

def preprocess_texts(texts):
    preprocessed_texts = [preprocess_text(text) for text in texts]
    # Further preprocess the texts using simple_preprocess function (deacc for removing accents)
    preprocessed_texts = [simple_preprocess(text, deacc=True) for text in preprocessed_texts]
    return preprocessed_texts

data_words = preprocess_texts(data_preprocessed)

# %% [markdown]
# <h1>What do we mean by Bi-grams and tri-grams ?</h1>
# <blockquote>
# Bigrams and trigrams are types of n-grams, which are contiguous sequences of n items (typically words) in a text.
#
# - Bigrams: A bigram is a sequence of two consecutive words that commonly occur together. It captures the relationship and co-occurrence patterns between two adjacent words in a text. For example, in the sentence "I love chocolate," the bigrams would be "I love" and "love chocolate." Bigrams can help identify common phrases or expressions.
#
# - Trigrams: A trigram is a sequence of three consecutive words that commonly occur together. It extends the concept of bigrams by considering the relationship between three adjacent words. For example, in the sentence "I want to eat pizza," the trigram would be "I want to" and "want to eat." Trigrams provide a richer context and can capture more complex language patterns.
#
# Both bigrams and trigrams are used in natural language processing tasks such as text analysis, language modeling, and information retrieval to capture the local dependencies and context within a text. They are generated by considering the frequency and co-occurrence of word sequences in a given corpus or dataset.
# </blockquote>

# %%
# Creating dictionary and corpus


# Function to create phrases (bigrams and trigrams) from the given texts
def create_phrases(texts, min_count=5, threshold=100):
    # Creating bigram phrases
    bigram_phrases = gensim.models.Phrases(texts, min_count=min_count, threshold=threshold)
    # Creating trigram phrases
    trigram_phrases = gensim.models.Phrases(bigram_phrases[texts], threshold=threshold)
    # Creating bigram and trigram models
    bigram = gensim.models.phrases.Phraser(bigram_phrases)
    trigram = gensim.models.phrases.Phraser(trigram_phrases)
    # Applying the bigram and trigram models to the texts
    data_bigrams = [bigram[doc] for doc in texts]
    data_bigrams_trigrams = [trigram[bigram[doc]] for doc in data_bigrams]

    return data_bigrams_trigrams

data_bigrams_trigrams = create_phrases(data_words)

# Creating a dictionary from the preprocessed texts
id2word = corpora.Dictionary(data_bigrams_trigrams)

# Creating a corpus (bag of words representation) from the preprocessed texts
corpus = [id2word.doc2bow(text) for text in data_bigrams_trigrams]

tfidf = TfidfModel(corpus, id2word=id2word)

low_value = 0.03
words  = []
words_missing_in_tfidf = []
for i in range(len(corpus)):
    bow = corpus[i]
    low_value_words = [] 
    tfidf_ids = [id for id, value in tfidf[bow]]
    bow_ids = [id for id, value in bow]
    low_value_words = [id for id, value in tfidf[bow] if value < low_value]
    drops = low_value_words + words_missing_in_tfidf
    for item in drops:
        words.append(id2word[item])
    words_missing_in_tfidf = [id for id in bow_ids if id not in tfidf_ids]

    new_bow = [b for b in bow if b[0] not in low_value_words and b[0] not in words_missing_in_tfidf]
    corpus[i] = new_bow

# %% [markdown]
# <details class="alert alert-success">
#     <summary>
# <h2 style="font-family:consolas;font-size:200%;margin-bottom:15px">What is TF-IDF and how does it work ? (Clickable)</h2>
#     </summary>
#     <body>
# <hr>
#
#
#
# - When we analyze a bunch of documents, we often want to know which words are most important in each document. TF-IDF is a technique that helps us identify those important words.
#
# ## Here's how it works:
#
# >TF (term frequency) measures how often a word appears in a document. The more times a word appears, the higher its TF score.
# IDF (inverse document frequency) measures how common or rare a word is across all documents in a collection. The rarer the word, the higher its IDF score.<br>
# TF-IDF combines both TF and IDF scores to calculate a final score for each word. The higher the TF-IDF score for a word in a document, the more important that word is to that document.<br>
# In summary, TF-IDF helps us identify the most important words in a document by considering how often they appear in the document and how common or rare they are across a collection of documents. We can use these important words as features for various NLP tasks like text classification, clustering, and information retrieval.<br>
#
# The maths behind it is not that awful. <br>
# >TF-IDF${i,j}$ = TF${i,j}$ $\times$ log$\frac{N}{df_i}$
#
# >where:
#
# > TF$_{i,j}$ is the term frequency of the $i$th word in the $j$th document
# N is the total number of documents in the corpus
# df$_i$ is the number of documents that contain the $i$th word.
# - <details>
#     <summary> <h4 style="color: green;">Useful links </h4> </summary>
#     <body>
#         <a href="https://www.youtube.com/watch?v=3eoX_waysy4">Calculate TF-IDF in NLP (Simple Example) - Data Science Garage</a> <br>
#     </body>
#     </details>
#     </body>

# %%
#==============================================================================
# LDA model: Automated selection of optimal number of clusters
#==============================================================================

#==============================================================================
# start_num_topics = 5
# end_num_topics = 20
# step = 1

# coherence_scores = []
# perplexity_scores = []

# for num_topics in range(start_num_topics, end_num_topics + 1, step):
#     lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus[:-1],
#                                                id2word=id2word,
#                                                num_topics=num_topics,
#                                                random_state=100,
#                                                update_every=1,
#                                                chunksize=100,
#                                                passes=10,
#                                                alpha="auto")
#     coherence_model = CoherenceModel(model=lda_model, texts=data_bigrams_trigrams, dictionary=id2word, coherence='c_v')
#     coherence_score = coherence_model.get_coherence()
#     perplexity_score = lda_model.log_perplexity(corpus)
#     coherence_scores.append(coherence_score)
#     perplexity_scores.append(perplexity_score)

# # Find the index of the maximum coherence score
# optimal_index = np.argmax(coherence_scores)

#************************************************************************************
# Calculate the optimal number of topics based on the index and step size
#************************************************************************************

# optimal_num_topics = start_num_topics + optimal_index * step
# print("Optimal number of topics:", optimal_num_topics) ==> 17
# print("Coherence score:", coherence_scores[optimal_index]) ==> 0.489
# print("Perplexity score:", perplexity_scores[optimal_index]) ==> -8.633

# Took about 14min to run
#==============================================================================

optimal_num_topics = 17
# Train the LDA model with the optimal number of topics
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus[:-1],
                                           id2word=id2word,
                                           num_topics=optimal_num_topics,
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha="auto")

lda_model.save("test_model.model")
new_model = gensim.models.ldamodel.LdaModel.load("test_model.model")

# %%
# Visualizing the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word, mds="mmds", R=30)
vis
# Out:
# D:\Programs\Anaconda\lib\site-packages\sklearn\manifold\_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 6      0.121342  0.417681       1        1  14.380731
# 16    -0.438270  0.103255       2        1  10.945248
# 13     0.072429  0.084097       3        1   7.822432
# 9     -0.295470  0.338565       4        1   7.636109
# 1     -0.075472  0.412476       5        1   7.200063
# 3      0.134148 -0.375825       6        1   7.159036
# 8      0.367006 -0.262710       7        1   6.600820
# 10     0.437498 -0.023640       8        1   6.135465
# 7      0.256506  0.281495       9        1   6.117402
# 2      0.241548 -0.127319      10        1   4.741967
# 12     0.416100  0.167635      11        1   3.982282
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def visualize_word_clouds(lda_model, num_topics):
    fig, axes = plt.subplots(nrows=num_topics, ncols=1, figsize=(8, 8*num_topics))

    for topic in range(num_topics):
        word_weights = lda_model.show_topic(topic, topn=30)
        topic_words = {word: weight for word, weight in word_weights}
        wordcloud = WordCloud(background_color='white').generate_from_frequencies(topic_words)

        axes[topic].imshow(wordcloud, interpolation='bilinear')
        axes[topic].set_title(f'Topic {topic+1}')
        axes[topic].axis('off')

    plt.tight_layout()
    plt.show()

num_topics = 17
visualize_word_clouds(lda_model, num_topics)

# %%
# Word2Vec model
model_w2v = Word2Vec(data_bigrams_trigrams, min_count=5)
model_w2v.save('model_w2v.bin')
new_w2v_model = Word2Vec.load('model_w2v.bin')

keyword = "climate"
res = new_w2v_model.wv.similar_by_word(keyword, topn=5)
for word, similarity in res:
    print(word, similarity)
# Out:
# global_warming 0.8015861511230469
# dramatically 0.729938268661499
# crisis 0.7015016674995422
# economic_growth 0.676984429359436
# ocean_acidification 0.6662750244140625

# %%
# Topic Labeling using Word2Vec
def find_similar_words(word, topn=5):
    similar_words = new_w2v_model.wv.similar_by_word(word, topn=topn)
    return [word for word, similarity in similar_words]

def label_topics(topic_keywords, topn=5):
    labeled_topics = []
    for topic in topic_keywords:
        topic_label = []
        for keyword, _ in topic:
            similar_words = find_similar_words(keyword, topn=topn)
            topic_label.extend(similar_words)
        labeled_topics.append(topic_label)
    return labeled_topics

# Get the topic keywords from the LDA model
topic_keywords = [lda_model.show_topic(topic_num, topn=10) for topic_num in range(lda_model.num_topics)]

# Label the topics using Word2Vec
labeled_topics = label_topics(topic_keywords, topn=5)

# Print the labeled topics
for topic_num, topic_label in enumerate(labeled_topics):
    print(f"Topic {topic_num}: {', '.join(topic_label)}")
# Out:
# Topic 0: urban, neighborhood, slum, park, town, building, construction, bridge, design, prototype, partner, organization, local, rural, support, designer, architect, engineer, architecture, prototype, far_flung, anywhere, city, slum, northern, fare_civilization, dimension, liminal, exploration, vastness, bridge, tower, build, downtown, apartment, town, village, resident, suburb, apartment, apartment, bus, sidewalk, park, hotel, architectural, creation, realm, ecology, collaboration
# Topic 1: solve, challenge, solution, tackle, issue, vision, optimistic, possibility, hopefully, hope, concept, inspiration, crazy, notion, innovation, engineer, team, project, convince, hard, competition, colleague, volunteer, staff, project, tackle, problem, fix, address, solution, global_warming, dramatically, crisis, economic_growth, ocean_acidification, housing, international, rural, agency, private, problem, solve, alternative, frugal, tackle, huge, small, deal, fan, large
# ...

# %%
# TESTING THE MODEL
def load_main(file_path):
    main = pd.read_csv(file_path)
    return main

main_data = load_main('ted_main.csv')

# %%
#Choose the id of the talk to test the model
id_talk = 1
#Get the transcript of the talk
transcript = transcripts[id_talk]
#What is interesting in the main_data is the column 'tags'
#and the column 'url'
tags = main_data.iloc[id_talk]['tags']
url = main_data.iloc[id_talk]['url']

print("Dataset information: ")
print(f"This ted talk is about {tags}")
print(f"Here is the link to the talk: {url}")
# Out:
# Dataset information:
# This ted talk is about ['alternative energy', 'cars', 'climate change', 'culture', 'environment', 'global issues', 'science', 'sustainability', 'technology']
# Here is the link to the talk: https://www.ted.com/talks/al_gore_on_averting_climate_crisis

# %%
test_doc = corpus[id_talk]
vector = new_model[test_doc]

def sort_by_value(sub_li):
    sub_li.sort(key=lambda x: x[1])
    return sub_li[::-1]

new_vector = sort_by_value(vector)
new_vector = [item for item in new_vector if item[1] > 0.1]

print("Model prediction: ")
print(f"This Ted Talk belongs to topic {new_vector[0][0]} with a relevance score of {new_vector[0][1]}")
print(f"Topic keywords: {labeled_topics[new_vector[0][0]]}")
# Out:
# Model prediction:
# This Ted Talk belongs to topic 1 with a relevance score of 0.42939791083335876
# Topic keywords: ['solve', 'challenge', 'solution', 'tackle', 'issue', 'vision', 'optimistic', 'possibility', 'hopefully', 'hope', 'concept', 'inspiration', 'crazy', 'notion', 'innovation', 'engineer', 'team', 'project', 'convince', 'hard', 'competition', 'colleague', 'volunteer', 'staff', 'project', 'tackle', 'problem', 'fix', 'address', 'solution', 'global_warming', 'dramatically', 'crisis', 'economic_growth', 'ocean_acidification', 'housing', 'international', 'rural', 'agency', 'private', 'problem', 'solve', 'alternative', 'frugal', 'tackle', 'huge', 'small', 'deal', 'fan', 'large']
